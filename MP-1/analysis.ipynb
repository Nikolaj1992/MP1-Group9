# %%
# !pip install pandas openpyxl xlrd
# Out:
# Requirement already satisfied: pandas in c:\users\nifje\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\nifje\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: xlrd in c:\users\nifje\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nifje\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nifje\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nifje\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nifje\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in c:\users\nifje\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\nifje\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# %run "Code/functions.ipynb"

# Load Excel file
df = load_excel('Data/FSI-2023-DOWNLOAD (1).xls')

print("Information about the dataset:")
print(f"Number of rows: {len(df)}")
print(f"Number of columns: {len(df.columns)}")
print("\nColumns in dataset:")
print(df.columns.tolist())
print("\nFirst 5 rows of data:")
print(df.head())


clean_df = clean_data(df)


visualize_data(clean_df)
# Out:
# Information about the dataset:
# Number of rows: 179
# Number of columns: 16
#
# Columns in dataset:
# ['Country', 'Year', 'Rank', 'Total', 'S1: Demographic Pressures', 'S2: Refugees and IDPs', 'C3: Group Grievance', 'E3: Human Flight and Brain Drain', 'E2: Economic Inequality', 'E1: Economy', 'P1: State Legitimacy', 'P2: Public Services', 'P3: Human Rights', 'C1: Security Apparatus', 'C2: Factionalized Elites', 'X1: External Intervention']
#
# First 5 rows of data:
#                      Country  Year Rank  Total  S1: Demographic Pressures  \
# 0                    Somalia  2023  1st  111.9                       10.0
# 1                      Yemen  2023  2nd  108.9                        9.6
# 2                South Sudan  2023  3rd  108.5                        9.7
# 3  Congo Democratic Republic  2023  4th  107.2                        9.7
# 4                      Syria  2023  5th  107.1                        7.4
#
#    S2: Refugees and IDPs  C3: Group Grievance  \
# 0                    9.0                  8.7
# 1                    9.6                  8.8
# 2                   10.0                  8.6
# 3                    9.8                  9.4
# 4                    9.1                  9.1
#
#    E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  \
# 0                               8.6                      9.1          9.5
# 1                               6.4                      7.9          9.9
# 2                               6.5                      8.6          8.6
# 3                               6.4                      8.4          8.1
# 4                               8.0                      6.5          9.6
#
#    P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                   9.6                  9.8               9.0
# 1                   9.8                  9.6               9.6
# 2                   9.8                  9.7               8.7
# 3                   9.3                  9.3               9.3
# 4                  10.0                  9.0               9.1
#
#    C1: Security Apparatus  C2: Factionalized Elites  X1: External Intervention
# 0                     9.5                      10.0                        9.1
# 1                     8.6                       9.9                        9.2
# 2                     9.9                       9.2                        9.2
# 3                     8.8                       9.6                        9.1
# 4                     9.4                       9.9                       10.0
# C:\Users\nifje\AppData\Local\Temp\ipykernel_30976\2050123866.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10, x='Total', y='Country', palette='rocket')
# C:\Users\nifje\AppData\Local\Temp\ipykernel_30976\2050123866.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_10, x='Total', y='Country', palette='rocket_r')
# Statistical Insights:
# Global average FSI score: 65.83
# Standard deviation: 23.97
#
# Top 3 most correlated indicators:
# P1: State Legitimacy & P3: Human Rights: 0.91
# P3: Human Rights & P1: State Legitimacy: 0.91
# P1: State Legitimacy & C2: Factionalized Elites: 0.86
#
#     =====================================
#          BOSS BATTLE BEGUN
#     =====================================
#                         /\__/\
#       Hunter1  Hunter2    |ಠ ಠ|
#        \[T]/   \[+]/     \▼▼/
#         |=|     |†|      /^^^^^\
#        / \     / \     <<|||||>>
#
#
#     =====================================
#          BOSS BATTLE BEGUN
#     =====================================
